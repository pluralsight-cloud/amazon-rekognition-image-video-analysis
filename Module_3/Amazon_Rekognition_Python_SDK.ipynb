# %% [markdown]
# ## Install Boto3 to Access AWS APIs

# %% [markdown]
# Boto3 is the official Python package from AWS that enables developers to programmatically interact with and manage different AWS services, like Polly.
#
# To know more about Boto3, please visit this link: https://boto3.amazonaws.com/v1/documentation/api/latest/index.html

# %%
#!pip3 install boto3

# %% [markdown]
# To know more about how to create and manage access keys, visit this link: https://docs.aws.amazon.com/IAM/latest/UserGuide/id_root-user_manage_add-key.html
#
# To know more about how to configure environment variables, visit this link: https://docs.aws.amazon.com/cli/v1/userguide/cli-configure-envvars.html

# %%
import os
os.environ['AWS_ACCESS_KEY_ID'] = 'YOUR_AWS_ACCESS_KEY'
os.environ['AWS_SECRET_ACCESS_KEY'] = 'AWS_SECRET_ACCESS_KEY'
os.environ['AWS_DEFAULT_REGION'] = 'YOUR_REGION'

# %% [markdown]
# ## Image Analysis Tasks Using Amazon Rekognition APIs

# %% [markdown]
# ### Request Format
# To know more about the request format for the detect_labels API, visit this link: https://docs.aws.amazon.com/rekognition/latest/APIReference/API_DetectLabels.html

# %%
{
   "Features": [ "string" ], # Valid values: GENERAL_LABELS, IMAGE_PROPERTIES
   "Image": { 
      "Bytes": blob,
      "S3Object": { 
         "Bucket": "string",
         "Name": "string",
         "Version": "string"
      }
   },
   "MaxLabels": number,
   "MinConfidence": number,
   "Settings": { 
      "GeneralLabels": { 
         "LabelCategoryExclusionFilters": [ "string" ],
         "LabelCategoryInclusionFilters": [ "string" ],
         "LabelExclusionFilters": [ "string" ],
         "LabelInclusionFilters": [ "string" ]
      },
      "ImageProperties": { 
         "MaxDominantColors": number
      }
   }
}

# %% [markdown]
# ### Input Image
# ![image](M3_C1_Image_Object_Scenes.JPEG)

# %%
import boto3
rekognition_client = boto3.client('rekognition')

# %%
with open('M3_C1_Image_Object_Scenes.JPEG', 'rb') as image_file:
    image_bytes = image_file.read()

# %%
detect_label_response = rekognition_client.detect_labels(
    Image={
        'Bytes': image_bytes
    },
    MaxLabels=10,
    MinConfidence=70
)

# %%
detect_label_response
# Out:
# {'Labels': [{'Name': 'Transportation',
#    'Confidence': 99.99304962158203,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Truck',
#    'Confidence': 99.99304962158203,
#    'Instances': [{'BoundingBox': {'Width': 0.3996747136116028,
#       'Height': 0.3106033205986023,
#       'Left': 0.43116289377212524,
#       'Top': 0.5181705355644226},
#      'Confidence': 99.99304962158203}],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Vehicle',
#    'Confidence': 99.99304962158203,
#    'Instances': [],
#    'Parents': [{'Name': 'Transportation'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Car',
#    'Confidence': 98.71708679199219,
#    'Instances': [{'BoundingBox': {'Width': 0.030874917283654213,
#       'Height': 0.03783337399363518,
#       'Left': 0.8264957666397095,
#       'Top': 0.6310374736785889},
#      'Confidence': 98.71708679199219},
#     {'BoundingBox': {'Width': 0.02686859853565693,
#       'Height': 0.01993090845644474,
#       'Left': 0.8660966157913208,
#       'Top': 0.6195803880691528},
#      'Confidence': 96.52978515625},
#     {'BoundingBox': {'Width': 0.0223582424223423,
#       'Height': 0.022302551195025444,
#       'Left': 0.890416145324707,
#       'Top': 0.6032522320747375},
#      'Confidence': 76.86870574951172}],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [{'Name': 'Automobile'}],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'License Plate',
#    'Confidence': 93.67101287841797,
#    'Instances': [],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Road',
#    'Confidence': 92.01030731201172,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Transport and Logistics'}]},
#   {'Name': 'Van',
#    'Confidence': 79.66548919677734,
#    'Instances': [],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]}],
#  'LabelModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': '15d2bf5e-11b4-47b7-8068-dd96a7c54c61',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '15d2bf5e-11b4-47b7-8068-dd96a7c54c61',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1869',
#    'date': 'Thu, 16 Oct 2025 19:16:22 GMT'},
#   'RetryAttempts': 0}}

# %%
with open('M3_C1_Image_Content_Moderation.jpeg', 'rb') as image_file:
    image_bytes = image_file.read()

# %%
detect_moderation_label_response = rekognition_client.detect_moderation_labels(
    Image={
        'Bytes': image_bytes
    },
    MinConfidence=70
)

# %%
detect_moderation_label_response
# Out:
# {'ModerationLabels': [{'Confidence': 99.0968017578125,
#    'Name': 'Blood & Gore',
#    'ParentName': 'Graphic Violence',
#    'TaxonomyLevel': 3},
#   {'Confidence': 99.0968017578125,
#    'Name': 'Graphic Violence',
#    'ParentName': 'Violence',
#    'TaxonomyLevel': 2},
#   {'Confidence': 99.0968017578125,
#    'Name': 'Violence',
#    'ParentName': '',
#    'TaxonomyLevel': 1}],
#  'ModerationModelVersion': '7.0',
#  'ContentTypes': [],
#  'ResponseMetadata': {'RequestId': 'ca0fefd9-198a-486f-8b9b-cd7bfbcda093',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'ca0fefd9-198a-486f-8b9b-cd7bfbcda093',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '359',
#    'date': 'Thu, 16 Oct 2025 19:16:37 GMT'},
#   'RetryAttempts': 0}}

# %%
with open('M3_C1_Image_Text_Detection.jpg', 'rb') as image_file:
    image_bytes = image_file.read()

# %%
detect_text_response = rekognition_client.detect_text(
    Image={
        'Bytes': image_bytes
    },
)

# %% [markdown]
# **Documentation links for the APIs**:
# detect_labels: https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/rekognition/client/detect_labels.html#
#
# **detect_moderation_labels**: https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/rekognition/client/detect_moderation_labels.html#
#
# **detect_text**: https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/rekognition/client/detect_text.html#
#
# **Rekognition API reference**: https://docs.aws.amazon.com/rekognition/latest/dg/API_Reference.html

# %%
detect_text_response
# Out:
# {'TextDetections': [{'DetectedText': 'ANIMAL',
#    'Type': 'LINE',
#    'Id': 0,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.4580078125,
#      'Height': 0.07297325134277344,
#      'Left': 0.2421875,
#      'Top': 0.2309703826904297},
#     'Polygon': [{'X': 0.2421875, 'Y': 0.2309703826904297},
#      {'X': 0.7001953125, 'Y': 0.2309703826904297},
#      {'X': 0.7001953125, 'Y': 0.3039436340332031},
#      {'X': 0.2421875, 'Y': 0.3039436340332031}]}},
#   {'DetectedText': 'FARM',
#    'Type': 'LINE',
#    'Id': 1,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.3193359375,
#      'Height': 0.07230377197265625,
#      'Left': 0.2470703125,
#      'Top': 0.3226890563964844},
#     'Polygon': [{'X': 0.2470703125, 'Y': 0.3226890563964844},
#      {'X': 0.56640625, 'Y': 0.3226890563964844},
#      {'X': 0.56640625, 'Y': 0.3949928283691406},
#      {'X': 0.2470703125, 'Y': 0.3949928283691406}]}},
#   {'DetectedText': 'GEORGE ORWELL',
#    'Type': 'LINE',
#    'Id': 2,
#    'Confidence': 99.48524475097656,
#    'Geometry': {'BoundingBox': {'Width': 0.4163910448551178,
#      'Height': 0.03011411428451538,
#      'Left': 0.24396055936813354,
#      'Top': 0.4150579273700714},
#     'Polygon': [{'X': 0.24416032433509827, 'Y': 0.4150579273700714},
#      {'X': 0.6603516340255737, 'Y': 0.41641685366630554},
#      {'X': 0.6601518392562866, 'Y': 0.4451720416545868},
#      {'X': 0.24396055936813354, 'Y': 0.44381311535835266}]}},
#   {'DetectedText': 'Art Brenner',
#    'Type': 'LINE',
#    'Id': 3,
#    'Confidence': 97.24433898925781,
#    'Geometry': {'BoundingBox': {'Width': 0.16432298719882965,
#      'Height': 0.028105497360229492,
#      'Left': 0.7651979923248291,
#      'Top': 0.9537869691848755},
#     'Polygon': [{'X': 0.7667527794837952, 'Y': 0.9537869691848755},
#      {'X': 0.9295210242271423, 'Y': 0.9589769840240479},
#      {'X': 0.9279662370681763, 'Y': 0.981892466545105},
#      {'X': 0.7651979923248291, 'Y': 0.9767024517059326}]}},
#   {'DetectedText': 'ANIMAL',
#    'Type': 'WORD',
#    'Id': 4,
#    'ParentId': 0,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.4580078125,
#      'Height': 0.07297325134277344,
#      'Left': 0.2421875,
#      'Top': 0.2309703826904297},
#     'Polygon': [{'X': 0.2421875, 'Y': 0.2309703826904297},
#      {'X': 0.7001953125, 'Y': 0.2309703826904297},
#      {'X': 0.7001953125, 'Y': 0.3039436340332031},
#      {'X': 0.2421875, 'Y': 0.3039436340332031}]}},
#   {'DetectedText': 'FARM',
#    'Type': 'WORD',
#    'Id': 5,
#    'ParentId': 1,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.3193359375,
#      'Height': 0.07230377197265625,
#      'Left': 0.2470703125,
#      'Top': 0.3226890563964844},
#     'Polygon': [{'X': 0.2470703125, 'Y': 0.3226890563964844},
#      {'X': 0.56640625, 'Y': 0.3226890563964844},
#      {'X': 0.56640625, 'Y': 0.3949928283691406},
#      {'X': 0.2470703125, 'Y': 0.3949928283691406}]}},
#   {'DetectedText': 'GEORGE',
#    'Type': 'WORD',
#    'Id': 6,
#    'ParentId': 2,
#    'Confidence': 99.29268646240234,
#    'Geometry': {'BoundingBox': {'Width': 0.19274532794952393,
#      'Height': 0.029013395309448242,
#      'Left': 0.24396538734436035,
#      'Top': 0.4150582551956177},
#     'Polygon': [{'X': 0.24425990879535675, 'Y': 0.4150582551956177},
#      {'X': 0.4367107152938843, 'Y': 0.41600745916366577},
#      {'X': 0.4364161789417267, 'Y': 0.4440716505050659},
#      {'X': 0.24396538734436035, 'Y': 0.4431224465370178}]}},
#   {'DetectedText': 'ORWELL',
#    'Type': 'WORD',
#    'Id': 7,
#    'ParentId': 2,
#    'Confidence': 99.67781066894531,
#    'Geometry': {'BoundingBox': {'Width': 0.1953125,
#      'Height': 0.028118133544921875,
#      'Left': 0.46484375,
#      'Top': 0.4164161682128906},
#     'Polygon': [{'X': 0.46484375, 'Y': 0.4164161682128906},
#      {'X': 0.66015625, 'Y': 0.4164161682128906},
#      {'X': 0.66015625, 'Y': 0.4445343017578125},
#      {'X': 0.46484375, 'Y': 0.4445343017578125}]}},
#   {'DetectedText': 'Art',
#    'Type': 'WORD',
#    'Id': 8,
#    'ParentId': 3,
#    'Confidence': 97.53376007080078,
#    'Geometry': {'BoundingBox': {'Width': 0.0400390625,
#      'Height': 0.020084381103515625,
#      'Left': 0.7666015625,
#      'Top': 0.9560165405273438},
#     'Polygon': [{'X': 0.7666015625, 'Y': 0.9560165405273438},
#      {'X': 0.806640625, 'Y': 0.9560165405273438},
#      {'X': 0.806640625, 'Y': 0.9761009216308594},
#      {'X': 0.7666015625, 'Y': 0.9761009216308594}]}},
#   {'DetectedText': 'Brenner',
#    'Type': 'WORD',
#    'Id': 9,
#    'ParentId': 3,
#    'Confidence': 96.95492553710938,
#    'Geometry': {'BoundingBox': {'Width': 0.12374730408191681,
#      'Height': 0.026811718940734863,
#      'Left': 0.8057736754417419,
#      'Top': 0.9550808072090149},
#     'Polygon': [{'X': 0.807328462600708, 'Y': 0.9550808072090149},
#      {'X': 0.9295210242271423, 'Y': 0.9589770436286926},
#      {'X': 0.9279662370681763, 'Y': 0.9818925261497498},
#      {'X': 0.8057736754417419, 'Y': 0.977996289730072}]}}],
#  'TextModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': '3e3da8bc-3b5e-45a8-bc49-45b64f15f926',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '3e3da8bc-3b5e-45a8-bc49-45b64f15f926',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4018',
#    'date': 'Thu, 16 Oct 2025 19:16:53 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Analyze Responses

# %%
detect_label_response
# Out:
# {'Labels': [{'Name': 'Transportation',
#    'Confidence': 99.99304962158203,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Truck',
#    'Confidence': 99.99304962158203,
#    'Instances': [{'BoundingBox': {'Width': 0.3996747136116028,
#       'Height': 0.3106033205986023,
#       'Left': 0.43116289377212524,
#       'Top': 0.5181705355644226},
#      'Confidence': 99.99304962158203}],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Vehicle',
#    'Confidence': 99.99304962158203,
#    'Instances': [],
#    'Parents': [{'Name': 'Transportation'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Car',
#    'Confidence': 98.71708679199219,
#    'Instances': [{'BoundingBox': {'Width': 0.030874917283654213,
#       'Height': 0.03783337399363518,
#       'Left': 0.8264957666397095,
#       'Top': 0.6310374736785889},
#      'Confidence': 98.71708679199219},
#     {'BoundingBox': {'Width': 0.02686859853565693,
#       'Height': 0.01993090845644474,
#       'Left': 0.8660966157913208,
#       'Top': 0.6195803880691528},
#      'Confidence': 96.52978515625},
#     {'BoundingBox': {'Width': 0.0223582424223423,
#       'Height': 0.022302551195025444,
#       'Left': 0.890416145324707,
#       'Top': 0.6032522320747375},
#      'Confidence': 76.86870574951172}],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [{'Name': 'Automobile'}],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'License Plate',
#    'Confidence': 93.67101287841797,
#    'Instances': [],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]},
#   {'Name': 'Road',
#    'Confidence': 92.01030731201172,
#    'Instances': [],
#    'Parents': [],
#    'Aliases': [],
#    'Categories': [{'Name': 'Transport and Logistics'}]},
#   {'Name': 'Van',
#    'Confidence': 79.66548919677734,
#    'Instances': [],
#    'Parents': [{'Name': 'Transportation'}, {'Name': 'Vehicle'}],
#    'Aliases': [],
#    'Categories': [{'Name': 'Vehicles and Automotive'}]}],
#  'LabelModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': '15d2bf5e-11b4-47b7-8068-dd96a7c54c61',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '15d2bf5e-11b4-47b7-8068-dd96a7c54c61',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '1869',
#    'date': 'Thu, 16 Oct 2025 19:16:22 GMT'},
#   'RetryAttempts': 0}}

# %%
print("Detected Labels:")
for label in detect_label_response['Labels']:
    print(f"  {label['Name']} (Confidence: {label['Confidence']:.2f}%)")
# Out:
# Detected Labels:
#   Transportation (Confidence: 99.99%)
#   Truck (Confidence: 99.99%)
#   Vehicle (Confidence: 99.99%)
#   Car (Confidence: 98.72%)
#   License Plate (Confidence: 93.67%)
#   Road (Confidence: 92.01%)
#   Van (Confidence: 79.67%)

# %%
detect_moderation_label_response
# Out:
# {'ModerationLabels': [{'Confidence': 99.0968017578125,
#    'Name': 'Blood & Gore',
#    'ParentName': 'Graphic Violence',
#    'TaxonomyLevel': 3},
#   {'Confidence': 99.0968017578125,
#    'Name': 'Graphic Violence',
#    'ParentName': 'Violence',
#    'TaxonomyLevel': 2},
#   {'Confidence': 99.0968017578125,
#    'Name': 'Violence',
#    'ParentName': '',
#    'TaxonomyLevel': 1}],
#  'ModerationModelVersion': '7.0',
#  'ContentTypes': [],
#  'ResponseMetadata': {'RequestId': 'ca0fefd9-198a-486f-8b9b-cd7bfbcda093',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'ca0fefd9-198a-486f-8b9b-cd7bfbcda093',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '359',
#    'date': 'Thu, 16 Oct 2025 19:16:37 GMT'},
#   'RetryAttempts': 0}}

# %%
print("Moderation Labels:")
for label in detect_moderation_label_response['ModerationLabels']:
    print(f"  {label['Name']} (Confidence: {label['Confidence']:.2f}%)")
# Out:
# Moderation Labels:
#   Blood & Gore (Confidence: 99.10%)
#   Graphic Violence (Confidence: 99.10%)
#   Violence (Confidence: 99.10%)

# %%
detect_text_response
# Out:
# {'TextDetections': [{'DetectedText': 'ANIMAL',
#    'Type': 'LINE',
#    'Id': 0,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.4580078125,
#      'Height': 0.07297325134277344,
#      'Left': 0.2421875,
#      'Top': 0.2309703826904297},
#     'Polygon': [{'X': 0.2421875, 'Y': 0.2309703826904297},
#      {'X': 0.7001953125, 'Y': 0.2309703826904297},
#      {'X': 0.7001953125, 'Y': 0.3039436340332031},
#      {'X': 0.2421875, 'Y': 0.3039436340332031}]}},
#   {'DetectedText': 'FARM',
#    'Type': 'LINE',
#    'Id': 1,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.3193359375,
#      'Height': 0.07230377197265625,
#      'Left': 0.2470703125,
#      'Top': 0.3226890563964844},
#     'Polygon': [{'X': 0.2470703125, 'Y': 0.3226890563964844},
#      {'X': 0.56640625, 'Y': 0.3226890563964844},
#      {'X': 0.56640625, 'Y': 0.3949928283691406},
#      {'X': 0.2470703125, 'Y': 0.3949928283691406}]}},
#   {'DetectedText': 'GEORGE ORWELL',
#    'Type': 'LINE',
#    'Id': 2,
#    'Confidence': 99.48524475097656,
#    'Geometry': {'BoundingBox': {'Width': 0.4163910448551178,
#      'Height': 0.03011411428451538,
#      'Left': 0.24396055936813354,
#      'Top': 0.4150579273700714},
#     'Polygon': [{'X': 0.24416032433509827, 'Y': 0.4150579273700714},
#      {'X': 0.6603516340255737, 'Y': 0.41641685366630554},
#      {'X': 0.6601518392562866, 'Y': 0.4451720416545868},
#      {'X': 0.24396055936813354, 'Y': 0.44381311535835266}]}},
#   {'DetectedText': 'Art Brenner',
#    'Type': 'LINE',
#    'Id': 3,
#    'Confidence': 97.24433898925781,
#    'Geometry': {'BoundingBox': {'Width': 0.16432298719882965,
#      'Height': 0.028105497360229492,
#      'Left': 0.7651979923248291,
#      'Top': 0.9537869691848755},
#     'Polygon': [{'X': 0.7667527794837952, 'Y': 0.9537869691848755},
#      {'X': 0.9295210242271423, 'Y': 0.9589769840240479},
#      {'X': 0.9279662370681763, 'Y': 0.981892466545105},
#      {'X': 0.7651979923248291, 'Y': 0.9767024517059326}]}},
#   {'DetectedText': 'ANIMAL',
#    'Type': 'WORD',
#    'Id': 4,
#    'ParentId': 0,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.4580078125,
#      'Height': 0.07297325134277344,
#      'Left': 0.2421875,
#      'Top': 0.2309703826904297},
#     'Polygon': [{'X': 0.2421875, 'Y': 0.2309703826904297},
#      {'X': 0.7001953125, 'Y': 0.2309703826904297},
#      {'X': 0.7001953125, 'Y': 0.3039436340332031},
#      {'X': 0.2421875, 'Y': 0.3039436340332031}]}},
#   {'DetectedText': 'FARM',
#    'Type': 'WORD',
#    'Id': 5,
#    'ParentId': 1,
#    'Confidence': 100.0,
#    'Geometry': {'BoundingBox': {'Width': 0.3193359375,
#      'Height': 0.07230377197265625,
#      'Left': 0.2470703125,
#      'Top': 0.3226890563964844},
#     'Polygon': [{'X': 0.2470703125, 'Y': 0.3226890563964844},
#      {'X': 0.56640625, 'Y': 0.3226890563964844},
#      {'X': 0.56640625, 'Y': 0.3949928283691406},
#      {'X': 0.2470703125, 'Y': 0.3949928283691406}]}},
#   {'DetectedText': 'GEORGE',
#    'Type': 'WORD',
#    'Id': 6,
#    'ParentId': 2,
#    'Confidence': 99.29268646240234,
#    'Geometry': {'BoundingBox': {'Width': 0.19274532794952393,
#      'Height': 0.029013395309448242,
#      'Left': 0.24396538734436035,
#      'Top': 0.4150582551956177},
#     'Polygon': [{'X': 0.24425990879535675, 'Y': 0.4150582551956177},
#      {'X': 0.4367107152938843, 'Y': 0.41600745916366577},
#      {'X': 0.4364161789417267, 'Y': 0.4440716505050659},
#      {'X': 0.24396538734436035, 'Y': 0.4431224465370178}]}},
#   {'DetectedText': 'ORWELL',
#    'Type': 'WORD',
#    'Id': 7,
#    'ParentId': 2,
#    'Confidence': 99.67781066894531,
#    'Geometry': {'BoundingBox': {'Width': 0.1953125,
#      'Height': 0.028118133544921875,
#      'Left': 0.46484375,
#      'Top': 0.4164161682128906},
#     'Polygon': [{'X': 0.46484375, 'Y': 0.4164161682128906},
#      {'X': 0.66015625, 'Y': 0.4164161682128906},
#      {'X': 0.66015625, 'Y': 0.4445343017578125},
#      {'X': 0.46484375, 'Y': 0.4445343017578125}]}},
#   {'DetectedText': 'Art',
#    'Type': 'WORD',
#    'Id': 8,
#    'ParentId': 3,
#    'Confidence': 97.53376007080078,
#    'Geometry': {'BoundingBox': {'Width': 0.0400390625,
#      'Height': 0.020084381103515625,
#      'Left': 0.7666015625,
#      'Top': 0.9560165405273438},
#     'Polygon': [{'X': 0.7666015625, 'Y': 0.9560165405273438},
#      {'X': 0.806640625, 'Y': 0.9560165405273438},
#      {'X': 0.806640625, 'Y': 0.9761009216308594},
#      {'X': 0.7666015625, 'Y': 0.9761009216308594}]}},
#   {'DetectedText': 'Brenner',
#    'Type': 'WORD',
#    'Id': 9,
#    'ParentId': 3,
#    'Confidence': 96.95492553710938,
#    'Geometry': {'BoundingBox': {'Width': 0.12374730408191681,
#      'Height': 0.026811718940734863,
#      'Left': 0.8057736754417419,
#      'Top': 0.9550808072090149},
#     'Polygon': [{'X': 0.807328462600708, 'Y': 0.9550808072090149},
#      {'X': 0.9295210242271423, 'Y': 0.9589770436286926},
#      {'X': 0.9279662370681763, 'Y': 0.9818925261497498},
#      {'X': 0.8057736754417419, 'Y': 0.977996289730072}]}}],
#  'TextModelVersion': '3.0',
#  'ResponseMetadata': {'RequestId': '3e3da8bc-3b5e-45a8-bc49-45b64f15f926',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '3e3da8bc-3b5e-45a8-bc49-45b64f15f926',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '4018',
#    'date': 'Thu, 16 Oct 2025 19:16:53 GMT'},
#   'RetryAttempts': 0}}

# %%
print("Moderation Labels:")
for label in detect_text_response['TextDetections']:
    print(f"  {label['DetectedText']}")
# Out:
# Moderation Labels:
#   ANIMAL
#   FARM
#   GEORGE ORWELL
#   Art Brenner
#   ANIMAL
#   FARM
#   GEORGE
#   ORWELL
#   Art
#   Brenner

# %% [markdown]
# ## API Call Type
#
# **Synchronous**: When a synchronous API call is made, the calling program waits for the API to return a response before proceeding to the next line of code.
#
# **Asynchronous**: When an asynchronous API call is made, the calling program does not wait for the API to return a response. It submits the job and continues executing other tasks while the API call is processed in the background. Typically, there exists another API call that can be used to check the status of the job and get the response once the job is finished.
#
# **StartLabelDetection** API: https://docs.aws.amazon.com/rekognition/latest/APIReference/API_StartLabelDetection.html
#
# **GetLabelDetection** API: https://docs.aws.amazon.com/rekognition/latest/APIReference/API_GetLabelDetection.html
#
# **Video Dataset**: https://www.kaggle.com/datasets/mistag/short-videos

# %%
start_label_detection_response = rekognition_client.start_label_detection(
    Video={
        'S3Object': {
            'Bucket': 'rekognition-bucket-1000',
            'Name': 'input-output/M3_C3_Video_Label_Detection.mp4'
        }
    },
    MinConfidence = 90,
    # NotificationChannel={
    #     'SNSTopicArn': 'string',
    #     'RoleArn': 'string'
    # }
)

# %%
start_label_detection_response
# Out:
# {'JobId': '435542f8bbd899bce19c8aa01a77d8a1ae821f3e9007f10e5cf9286ce8a1b4e8',
#  'ResponseMetadata': {'RequestId': '45d0a8f9-a002-4001-a850-2604883dab96',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '45d0a8f9-a002-4001-a850-2604883dab96',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '76',
#    'date': 'Thu, 16 Oct 2025 19:32:49 GMT'},
#   'RetryAttempts': 0}}

# %%
start_label_detection_response['JobId']
# Out:
# '435542f8bbd899bce19c8aa01a77d8a1ae821f3e9007f10e5cf9286ce8a1b4e8'

# %%
get_label_detection_response = rekognition_client.get_label_detection(
    JobId='435542f8bbd899bce19c8aa01a77d8a1ae821f3e9007f10e5cf9286ce8a1b4e8',
    # MaxResults=123,
    # NextToken='string',
    # SortBy='NAME'|'TIMESTAMP',
    # AggregateBy='TIMESTAMPS'|'SEGMENTS'
)

# %%
response
# Out:
# {'JobStatus': 'SUCCEEDED',
#  'VideoMetadata': {'Codec': 'h264',
#   'DurationMillis': 13013,
#   'Format': 'QuickTime / MOV',
#   'FrameRate': 29.970029830932617,
#   'FrameHeight': 720,
#   'FrameWidth': 1280,
#   'ColorRange': 'LIMITED'},
#  'NextToken': 'P1wZBwkxhjLLbqB8eLfGM+NFbQS2vSEkhL5CEYembDphdH2+5/HQf4IjLWVhyrNNwffq79yC/Btm',
#  'Labels': [{'Timestamp': 33,
#    'Label': {'Name': 'Adult',
#     'Confidence': 52.446014404296875,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Animal',
#     'Confidence': 52.4047737121582,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Bakery',
#     'Confidence': 51.4705924987793,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Bowl',
#     'Confidence': 56.300533294677734,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Bread',
#     'Confidence': 55.026187896728516,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Brunch',
#     'Confidence': 99.9617691040039,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Buffet',
#     'Confidence': 51.08312225341797,
#     'Instances': [],
#     'Parents': [{'Name': 'Cafeteria'},
#      {'Name': 'Food'},
#      {'Name': 'Indoors'},
#      {'Name': 'Meal'},
#      {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Butcher Shop',
#     'Confidence': 52.66227340698242,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Cafeteria',
#     'Confidence': 57.249000549316406,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Clam',
#     'Confidence': 52.4047737121582,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Food'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'},
#      {'Name': 'Seafood'},
#      {'Name': 'Seashell'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Cream',
#     'Confidence': 52.47113800048828,
#     'Instances': [],
#     'Parents': [{'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [{'Name': 'Creme'}],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Deli',
#     'Confidence': 62.20136642456055,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Dessert',
#     'Confidence': 52.47113800048828,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Dish',
#     'Confidence': 59.000362396240234,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Eating',
#     'Confidence': 51.3912467956543,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Actions'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Electrical Device',
#     'Confidence': 50.39753723144531,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Technology and Computing'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Female',
#     'Confidence': 52.446014404296875,
#     'Instances': [],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Food',
#     'Confidence': 99.96488952636719,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Food Presentation',
#     'Confidence': 54.01863479614258,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Furniture',
#     'Confidence': 51.63711929321289,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Grocery Store',
#     'Confidence': 53.27299880981445,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Ice Cream',
#     'Confidence': 52.072383880615234,
#     'Instances': [],
#     'Parents': [{'Name': 'Cream'}, {'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Icing',
#     'Confidence': 52.217681884765625,
#     'Instances': [],
#     'Parents': [{'Name': 'Cream'}, {'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Indoors',
#     'Confidence': 58.325252532958984,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home and Indoors'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Invertebrate',
#     'Confidence': 52.4047737121582,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Lunch',
#     'Confidence': 59.24039840698242,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Market',
#     'Confidence': 55.956172943115234,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Meal',
#     'Confidence': 95.39302825927734,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Meat',
#     'Confidence': 82.05784606933594,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Pancake',
#     'Confidence': 50.082916259765625,
#     'Instances': [],
#     'Parents': [{'Name': 'Bread'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Pastry',
#     'Confidence': 50.761287689208984,
#     'Instances': [],
#     'Parents': [{'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Person',
#     'Confidence': 53.82527542114258,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Platter',
#     'Confidence': 51.46349334716797,
#     'Instances': [],
#     'Parents': [{'Name': 'Dish'}, {'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Pork',
#     'Confidence': 82.05784606933594,
#     'Instances': [{'BoundingBox': {'Width': 0.13153831660747528,
#        'Height': 0.11636500805616379,
#        'Left': 0.3925915062427521,
#        'Top': 0.6745462417602539},
#       'Confidence': 84.94416809082031},
#      {'BoundingBox': {'Width': 0.14369745552539825,
#        'Height': 0.149819016456604,
#        'Left': 0.2538064122200012,
#        'Top': 0.6718655824661255},
#       'Confidence': 79.99070739746094},
#      {'BoundingBox': {'Width': 0.12746863067150116,
#        'Height': 0.154866024851799,
#        'Left': 0.5232839584350586,
#        'Top': 0.6331058740615845},
#       'Confidence': 76.1605224609375},
#      {'BoundingBox': {'Width': 0.5068124532699585,
#        'Height': 0.4520769417285919,
#        'Left': 0.1508452594280243,
#        'Top': 0.4257800281047821},
#       'Confidence': 64.89091491699219}],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meat'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Restaurant',
#     'Confidence': 57.249000549316406,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Salad',
#     'Confidence': 50.5505256652832,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Sea Life',
#     'Confidence': 52.4047737121582,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Seafood',
#     'Confidence': 53.6988410949707,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Seashell',
#     'Confidence': 52.4047737121582,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Shop',
#     'Confidence': 84.11224365234375,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Snack',
#     'Confidence': 52.917381286621094,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Stew',
#     'Confidence': 51.30485916137695,
#     'Instances': [],
#     'Parents': [{'Name': 'Dish'}, {'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Supermarket',
#     'Confidence': 52.18020248413086,
#     'Instances': [],
#     'Parents': [{'Name': 'Grocery Store'},
#      {'Name': 'Indoors'},
#      {'Name': 'Market'},
#      {'Name': 'Shop'}],
#     'Aliases': [{'Name': 'Department Store'}],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Table',
#     'Confidence': 51.63711929321289,
#     'Instances': [],
#     'Parents': [{'Name': 'Furniture'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Tabletop',
#     'Confidence': 51.39859390258789,
#     'Instances': [],
#     'Parents': [{'Name': 'Furniture'}, {'Name': 'Table'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Text',
#     'Confidence': 53.17805862426758,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Text and Documents'}]}},
#   {'Timestamp': 33,
#    'Label': {'Name': 'Woman',
#     'Confidence': 52.446014404296875,
#     'Instances': [],
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Female'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Adult',
#     'Confidence': 68.47624206542969,
#     'Instances': [{'BoundingBox': {'Width': 0.1273912489414215,
#        'Height': 0.28721415996551514,
#        'Left': 0.21171577274799347,
#        'Top': 0.0},
#       'Confidence': 73.33474731445312}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Animal',
#     'Confidence': 50.80570983886719,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Bakery',
#     'Confidence': 53.8619384765625,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Bazaar',
#     'Confidence': 50.16128158569336,
#     'Instances': [],
#     'Parents': [{'Name': 'Market'}, {'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Beverage',
#     'Confidence': 50.14043426513672,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Drink'}],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Bowl',
#     'Confidence': 55.86975860595703,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Bread',
#     'Confidence': 57.48047637939453,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Breakfast',
#     'Confidence': 50.39004898071289,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Brunch',
#     'Confidence': 97.74668884277344,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Buffet',
#     'Confidence': 52.64248275756836,
#     'Instances': [],
#     'Parents': [{'Name': 'Cafeteria'},
#      {'Name': 'Food'},
#      {'Name': 'Indoors'},
#      {'Name': 'Meal'},
#      {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Butcher Shop',
#     'Confidence': 53.52404022216797,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Cafe',
#     'Confidence': 50.28428268432617,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Cafeteria',
#     'Confidence': 61.6607666015625,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Cheese',
#     'Confidence': 50.680335998535156,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Clam',
#     'Confidence': 50.76066589355469,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Food'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'},
#      {'Name': 'Seafood'},
#      {'Name': 'Seashell'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Cream',
#     'Confidence': 54.85112762451172,
#     'Instances': [],
#     'Parents': [{'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [{'Name': 'Creme'}],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Deli',
#     'Confidence': 85.18579864501953,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Dessert',
#     'Confidence': 54.85112762451172,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Dish',
#     'Confidence': 62.411781311035156,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Eating',
#     'Confidence': 50.77608871459961,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Actions'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Electrical Device',
#     'Confidence': 51.079261779785156,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Technology and Computing'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Female',
#     'Confidence': 68.47624206542969,
#     'Instances': [{'BoundingBox': {'Width': 0.1273912489414215,
#        'Height': 0.28721415996551514,
#        'Left': 0.21171577274799347,
#        'Top': 0.0},
#       'Confidence': 73.33474731445312}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Food',
#     'Confidence': 99.9465103149414,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Food Court',
#     'Confidence': 51.03049850463867,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Food Presentation',
#     'Confidence': 51.80669403076172,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Fruit',
#     'Confidence': 50.13733673095703,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Plant'}, {'Name': 'Produce'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Furniture',
#     'Confidence': 52.971317291259766,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Grocery Store',
#     'Confidence': 54.322635650634766,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Ice Cream',
#     'Confidence': 52.636749267578125,
#     'Instances': [],
#     'Parents': [{'Name': 'Cream'}, {'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Icing',
#     'Confidence': 54.82246398925781,
#     'Instances': [],
#     'Parents': [{'Name': 'Cream'}, {'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Indoors',
#     'Confidence': 64.84732055664062,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home and Indoors'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Invertebrate',
#     'Confidence': 50.76066589355469,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Juice',
#     'Confidence': 50.14043426513672,
#     'Instances': [],
#     'Parents': [{'Name': 'Beverage'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Lunch',
#     'Confidence': 63.67842483520508,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Market',
#     'Confidence': 55.98648452758789,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Meal',
#     'Confidence': 97.97041320800781,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Meat',
#     'Confidence': 72.3058853149414,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Pastry',
#     'Confidence': 52.5687141418457,
#     'Instances': [],
#     'Parents': [{'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Person',
#     'Confidence': 68.95427703857422,
#     'Instances': [{'BoundingBox': {'Width': 0.1273912489414215,
#        'Height': 0.28721415996551514,
#        'Left': 0.21171577274799347,
#        'Top': 0.0},
#       'Confidence': 73.33474731445312}],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Pizza',
#     'Confidence': 50.36949157714844,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Plant',
#     'Confidence': 50.13733673095703,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Plants and Flowers'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Plastic Wrap',
#     'Confidence': 50.58340072631836,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Plate',
#     'Confidence': 51.20873260498047,
#     'Instances': [{'BoundingBox': {'Width': 0.24256853759288788,
#        'Height': 0.09935351461172104,
#        'Left': 0.5281727910041809,
#        'Top': 0.2859068810939789},
#       'Confidence': 56.771629333496094}],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Platter',
#     'Confidence': 52.61763000488281,
#     'Instances': [],
#     'Parents': [{'Name': 'Dish'}, {'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Pork',
#     'Confidence': 72.3058853149414,
#     'Instances': [{'BoundingBox': {'Width': 0.12804369628429413,
#        'Height': 0.15101581811904907,
#        'Left': 0.5408922433853149,
#        'Top': 0.6317833065986633},
#       'Confidence': 74.72167205810547},
#      {'BoundingBox': {'Width': 0.1432081162929535,
#        'Height': 0.16488753259181976,
#        'Left': 0.2743539810180664,
#        'Top': 0.6488498449325562},
#       'Confidence': 59.81307601928711}],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meat'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Produce',
#     'Confidence': 50.13733673095703,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Restaurant',
#     'Confidence': 61.6607666015625,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Sandwich',
#     'Confidence': 51.12905502319336,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Sea Life',
#     'Confidence': 50.80570983886719,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Seafood',
#     'Confidence': 52.75579071044922,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Seashell',
#     'Confidence': 50.76066589355469,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Shop',
#     'Confidence': 91.68719482421875,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Snack',
#     'Confidence': 54.25692367553711,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Stew',
#     'Confidence': 51.26357650756836,
#     'Instances': [],
#     'Parents': [{'Name': 'Dish'}, {'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Supermarket',
#     'Confidence': 52.419647216796875,
#     'Instances': [],
#     'Parents': [{'Name': 'Grocery Store'},
#      {'Name': 'Indoors'},
#      {'Name': 'Market'},
#      {'Name': 'Shop'}],
#     'Aliases': [{'Name': 'Department Store'}],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Table',
#     'Confidence': 52.971317291259766,
#     'Instances': [],
#     'Parents': [{'Name': 'Furniture'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Tabletop',
#     'Confidence': 52.35116958618164,
#     'Instances': [],
#     'Parents': [{'Name': 'Furniture'}, {'Name': 'Table'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Text',
#     'Confidence': 53.628326416015625,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Text and Documents'}]}},
#   {'Timestamp': 533,
#    'Label': {'Name': 'Woman',
#     'Confidence': 68.47624206542969,
#     'Instances': [{'BoundingBox': {'Width': 0.1273912489414215,
#        'Height': 0.28721415996551514,
#        'Left': 0.21171577274799347,
#        'Top': 0.0},
#       'Confidence': 73.33474731445312}],
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Female'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Adult',
#     'Confidence': 55.78707504272461,
#     'Instances': [{'BoundingBox': {'Width': 0.11978866904973984,
#        'Height': 0.21217837929725647,
#        'Left': 0.22490349411964417,
#        'Top': 0.00013029988622292876},
#       'Confidence': 51.132659912109375}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Animal',
#     'Confidence': 52.74325942993164,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Appliance',
#     'Confidence': 52.518699645996094,
#     'Instances': [],
#     'Parents': [{'Name': 'Device'}, {'Name': 'Electrical Device'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home Appliances'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Art',
#     'Confidence': 50.070838928222656,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Bbq',
#     'Confidence': 51.991031646728516,
#     'Instances': [],
#     'Parents': [{'Name': 'Cooking'}, {'Name': 'Food'}, {'Name': 'Grilling'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Beverage',
#     'Confidence': 50.59178161621094,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Drink'}],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Bottle',
#     'Confidence': 50.70206069946289,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Everyday Objects'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Bowl',
#     'Confidence': 55.2595100402832,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Bread',
#     'Confidence': 68.0754623413086,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Breakfast',
#     'Confidence': 51.375030517578125,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Brunch',
#     'Confidence': 94.77106475830078,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Buffet',
#     'Confidence': 54.55046463012695,
#     'Instances': [],
#     'Parents': [{'Name': 'Cafeteria'},
#      {'Name': 'Food'},
#      {'Name': 'Indoors'},
#      {'Name': 'Meal'},
#      {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Bun',
#     'Confidence': 50.995521545410156,
#     'Instances': [],
#     'Parents': [{'Name': 'Bread'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Butcher Shop',
#     'Confidence': 52.79473876953125,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Cafe',
#     'Confidence': 50.526702880859375,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Cafeteria',
#     'Confidence': 88.0565185546875,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Cheese',
#     'Confidence': 50.68968963623047,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Citrus Fruit',
#     'Confidence': 50.54724884033203,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'},
#      {'Name': 'Fruit'},
#      {'Name': 'Plant'},
#      {'Name': 'Produce'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Clam',
#     'Confidence': 52.65726852416992,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Food'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'},
#      {'Name': 'Seafood'},
#      {'Name': 'Seashell'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Cooking',
#     'Confidence': 51.991031646728516,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Cream',
#     'Confidence': 53.35072326660156,
#     'Instances': [],
#     'Parents': [{'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [{'Name': 'Creme'}],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Deli',
#     'Confidence': 84.78195190429688,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Dessert',
#     'Confidence': 53.35072326660156,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Device',
#     'Confidence': 52.78309631347656,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Technology and Computing'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Dining Table',
#     'Confidence': 52.43223571777344,
#     'Instances': [],
#     'Parents': [{'Name': 'Furniture'}, {'Name': 'Table'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Dinner',
#     'Confidence': 51.206390380859375,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [{'Name': 'Supper'}],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Dish',
#     'Confidence': 88.2687759399414,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Electrical Device',
#     'Confidence': 53.112003326416016,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Technology and Computing'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Female',
#     'Confidence': 55.78707504272461,
#     'Instances': [{'BoundingBox': {'Width': 0.11978866904973984,
#        'Height': 0.21217837929725647,
#        'Left': 0.22490349411964417,
#        'Top': 0.00013029988622292876},
#       'Confidence': 51.132659912109375}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Fondue',
#     'Confidence': 50.9376335144043,
#     'Instances': [],
#     'Parents': [{'Name': 'Dish'}, {'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Food',
#     'Confidence': 99.93346405029297,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Food Court',
#     'Confidence': 51.01698684692383,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Fruit',
#     'Confidence': 51.0045166015625,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Plant'}, {'Name': 'Produce'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Furniture',
#     'Confidence': 55.54097366333008,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Grilling',
#     'Confidence': 51.991031646728516,
#     'Instances': [],
#     'Parents': [{'Name': 'Cooking'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Grocery Store',
#     'Confidence': 54.149227142333984,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Hot Dog',
#     'Confidence': 51.1340446472168,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Hot Pot',
#     'Confidence': 50.36156463623047,
#     'Instances': [],
#     'Parents': [{'Name': 'Dish'},
#      {'Name': 'Food'},
#      {'Name': 'Meal'},
#      {'Name': 'Stew'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Ice Cream',
#     'Confidence': 50.90233612060547,
#     'Instances': [],
#     'Parents': [{'Name': 'Cream'}, {'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Icing',
#     'Confidence': 53.33704376220703,
#     'Instances': [],
#     'Parents': [{'Name': 'Cream'}, {'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Indoors',
#     'Confidence': 88.462890625,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home and Indoors'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Invertebrate',
#     'Confidence': 52.65726852416992,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Juice',
#     'Confidence': 50.59178161621094,
#     'Instances': [],
#     'Parents': [{'Name': 'Beverage'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Lunch',
#     'Confidence': 88.35552215576172,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Market',
#     'Confidence': 54.805667877197266,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Meal',
#     'Confidence': 99.52088928222656,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Meat',
#     'Confidence': 54.429866790771484,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Pastry',
#     'Confidence': 50.77632522583008,
#     'Instances': [],
#     'Parents': [{'Name': 'Dessert'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Person',
#     'Confidence': 56.476341247558594,
#     'Instances': [{'BoundingBox': {'Width': 0.11978866904973984,
#        'Height': 0.21217837929725647,
#        'Left': 0.22490349411964417,
#        'Top': 0.00013029988622292876},
#       'Confidence': 51.132659912109375}],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Pita',
#     'Confidence': 50.01902389526367,
#     'Instances': [],
#     'Parents': [{'Name': 'Bread'}, {'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Pizza',
#     'Confidence': 52.42723083496094,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Plant',
#     'Confidence': 51.0045166015625,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Plants and Flowers'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Plastic Wrap',
#     'Confidence': 51.73320770263672,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Platter',
#     'Confidence': 54.463924407958984,
#     'Instances': [],
#     'Parents': [{'Name': 'Dish'}, {'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Porcelain',
#     'Confidence': 50.070838928222656,
#     'Instances': [],
#     'Parents': [{'Name': 'Art'}, {'Name': 'Pottery'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Pork',
#     'Confidence': 54.429866790771484,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meat'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Pottery',
#     'Confidence': 50.070838928222656,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Hobbies and Interests'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Produce',
#     'Confidence': 51.0045166015625,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Restaurant',
#     'Confidence': 88.0565185546875,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Sandwich',
#     'Confidence': 52.328697204589844,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Sea Life',
#     'Confidence': 52.74325942993164,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Seafood',
#     'Confidence': 54.81129837036133,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Seashell',
#     'Confidence': 52.65726852416992,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Shop',
#     'Confidence': 88.32283782958984,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Snack',
#     'Confidence': 54.83668518066406,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Stew',
#     'Confidence': 52.903079986572266,
#     'Instances': [],
#     'Parents': [{'Name': 'Dish'}, {'Name': 'Food'}, {'Name': 'Meal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Supermarket',
#     'Confidence': 51.54922103881836,
#     'Instances': [],
#     'Parents': [{'Name': 'Grocery Store'},
#      {'Name': 'Indoors'},
#      {'Name': 'Market'},
#      {'Name': 'Shop'}],
#     'Aliases': [{'Name': 'Department Store'}],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Table',
#     'Confidence': 55.54097366333008,
#     'Instances': [],
#     'Parents': [{'Name': 'Furniture'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Tabletop',
#     'Confidence': 51.75764083862305,
#     'Instances': [],
#     'Parents': [{'Name': 'Furniture'}, {'Name': 'Table'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Furniture and Furnishings'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Text',
#     'Confidence': 51.83129119873047,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Text and Documents'}]}},
#   {'Timestamp': 1034,
#    'Label': {'Name': 'Woman',
#     'Confidence': 55.78707504272461,
#     'Instances': [{'BoundingBox': {'Width': 0.11978866904973984,
#        'Height': 0.21217837929725647,
#        'Left': 0.22490349411964417,
#        'Top': 0.00013029988622292876},
#       'Confidence': 51.132659912109375}],
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Female'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Adult',
#     'Confidence': 65.86027526855469,
#     'Instances': [{'BoundingBox': {'Width': 0.11765098571777344,
#        'Height': 0.25206828117370605,
#        'Left': 0.2818344235420227,
#        'Top': 0.00030386351863853633},
#       'Confidence': 62.54571533203125}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Animal',
#     'Confidence': 52.83984375,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Appliance',
#     'Confidence': 50.709266662597656,
#     'Instances': [],
#     'Parents': [{'Name': 'Device'}, {'Name': 'Electrical Device'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home Appliances'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Baby',
#     'Confidence': 50.406349182128906,
#     'Instances': [{'BoundingBox': {'Width': 0.29308536648750305,
#        'Height': 0.22518116235733032,
#        'Left': 7.074217137414962e-06,
#        'Top': 0.7729061841964722},
#       'Confidence': 69.30873107910156}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Bacon',
#     'Confidence': 50.21415328979492,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meat'}, {'Name': 'Pork'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Bazaar',
#     'Confidence': 51.12295913696289,
#     'Instances': [],
#     'Parents': [{'Name': 'Market'}, {'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Bbq',
#     'Confidence': 61.757591247558594,
#     'Instances': [],
#     'Parents': [{'Name': 'Cooking'}, {'Name': 'Food'}, {'Name': 'Grilling'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Beverage',
#     'Confidence': 50.07170104980469,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Drink'}],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Bottle',
#     'Confidence': 51.427513122558594,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Everyday Objects'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Bowl',
#     'Confidence': 53.006561279296875,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Bread',
#     'Confidence': 57.52354049682617,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Brunch',
#     'Confidence': 64.2628173828125,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 1534,
#    'Label': {'Name': 'Buffet',
#     'Confidence': 54.840660095214844,
#     'Instances': [],
#     'Parents': [{'Name': 'Cafeteria'},
#      {'Name': 'Food'},
#      {'Name': 'Indoors'},
#      {'Name': 'Meal'},
#      {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
# ...
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Female'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Accessories',
#     'Confidence': 61.05949401855469,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Accessory'}],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Adult',
#     'Confidence': 98.32022857666016,
#     'Instances': [{'BoundingBox': {'Width': 0.15160226821899414,
#        'Height': 0.23932361602783203,
#        'Left': 0.5891270637512207,
#        'Top': 0.00033687337418086827},
#       'Confidence': 98.53932189941406},
#      {'BoundingBox': {'Width': 0.1416357457637787,
#        'Height': 0.2564947009086609,
#        'Left': 0.6940078139305115,
#        'Top': 0.0009818216785788536},
#       'Confidence': 96.82588195800781},
#      {'BoundingBox': {'Width': 0.21167635917663574,
#        'Height': 0.34855732321739197,
#        'Left': 0.11399401724338531,
#        'Top': 0.0010278320405632257},
#       'Confidence': 96.36065673828125}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Animal',
#     'Confidence': 81.27616119384766,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Bag',
#     'Confidence': 57.1350212097168,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Bazaar',
#     'Confidence': 52.34332275390625,
#     'Instances': [],
#     'Parents': [{'Name': 'Market'}, {'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Bbq',
#     'Confidence': 51.488582611083984,
#     'Instances': [],
#     'Parents': [{'Name': 'Cooking'}, {'Name': 'Food'}, {'Name': 'Grilling'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Butcher Shop',
#     'Confidence': 55.38105010986328,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Cafeteria',
#     'Confidence': 50.276084899902344,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Clam',
#     'Confidence': 81.27616119384766,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Food'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'},
#      {'Name': 'Seafood'},
#      {'Name': 'Seashell'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Cooking',
#     'Confidence': 51.488582611083984,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Fish',
#     'Confidence': 50.891075134277344,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}, {'Name': 'Sea Life'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Food',
#     'Confidence': 81.62142944335938,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Grilling',
#     'Confidence': 51.488582611083984,
#     'Instances': [],
#     'Parents': [{'Name': 'Cooking'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Grocery Store',
#     'Confidence': 51.013668060302734,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Handbag',
#     'Confidence': 57.1350212097168,
#     'Instances': [{'BoundingBox': {'Width': 0.03866415098309517,
#        'Height': 0.12338308990001678,
#        'Left': 0.7017404437065125,
#        'Top': 0.08561097085475922},
#       'Confidence': 68.0309829711914}],
#     'Parents': [{'Name': 'Accessories'}, {'Name': 'Bag'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Indoors',
#     'Confidence': 50.481441497802734,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home and Indoors'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Invertebrate',
#     'Confidence': 81.27616119384766,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Male',
#     'Confidence': 98.32022857666016,
#     'Instances': [{'BoundingBox': {'Width': 0.15160226821899414,
#        'Height': 0.23932361602783203,
#        'Left': 0.5891270637512207,
#        'Top': 0.00033687337418086827},
#       'Confidence': 98.53932189941406},
#      {'BoundingBox': {'Width': 0.1416357457637787,
#        'Height': 0.2564947009086609,
#        'Left': 0.6940078139305115,
#        'Top': 0.0009818216785788536},
#       'Confidence': 96.82588195800781},
#      {'BoundingBox': {'Width': 0.21167635917663574,
#        'Height': 0.34855732321739197,
#        'Left': 0.11399401724338531,
#        'Top': 0.0010278320405632257},
#       'Confidence': 96.36065673828125}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Man',
#     'Confidence': 98.32022857666016,
#     'Instances': [{'BoundingBox': {'Width': 0.15160226821899414,
#        'Height': 0.23932361602783203,
#        'Left': 0.5891270637512207,
#        'Top': 0.00033687337418086827},
#       'Confidence': 98.53932189941406},
#      {'BoundingBox': {'Width': 0.1416357457637787,
#        'Height': 0.2564947009086609,
#        'Left': 0.6940078139305115,
#        'Top': 0.0009818216785788536},
#       'Confidence': 96.82588195800781},
#      {'BoundingBox': {'Width': 0.21167635917663574,
#        'Height': 0.34855732321739197,
#        'Left': 0.11399401724338531,
#        'Top': 0.0010278320405632257},
#       'Confidence': 96.36065673828125}],
#     'Parents': [{'Name': 'Adult'}, {'Name': 'Male'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Market',
#     'Confidence': 73.52490234375,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Meat',
#     'Confidence': 53.10541915893555,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Mutton',
#     'Confidence': 52.99357604980469,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}, {'Name': 'Meat'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Person',
#     'Confidence': 98.32022857666016,
#     'Instances': [{'BoundingBox': {'Width': 0.15160226821899414,
#        'Height': 0.23932361602783203,
#        'Left': 0.5891270637512207,
#        'Top': 0.00033687337418086827},
#       'Confidence': 98.53932189941406},
#      {'BoundingBox': {'Width': 0.1416357457637787,
#        'Height': 0.2564947009086609,
#        'Left': 0.6940078139305115,
#        'Top': 0.0009818216785788536},
#       'Confidence': 96.82588195800781},
#      {'BoundingBox': {'Width': 0.21167635917663574,
#        'Height': 0.34855732321739197,
#        'Left': 0.11399401724338531,
#        'Top': 0.0010278320405632257},
#       'Confidence': 96.36065673828125}],
#     'Parents': [],
#     'Aliases': [{'Name': 'Human'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Restaurant',
#     'Confidence': 50.276084899902344,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Sea Life',
#     'Confidence': 81.27616119384766,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Seafood',
#     'Confidence': 81.27616119384766,
#     'Instances': [],
#     'Parents': [{'Name': 'Food'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Seashell',
#     'Confidence': 81.27616119384766,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Nature and Outdoors'}]}},
#   {'Timestamp': 11044,
#    'Label': {'Name': 'Shop',
#     'Confidence': 63.917633056640625,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Accessories',
#     'Confidence': 57.453834533691406,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [{'Name': 'Accessory'}],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Adult',
#     'Confidence': 98.54073333740234,
#     'Instances': [{'BoundingBox': {'Width': 0.15138936042785645,
#        'Height': 0.24043001234531403,
#        'Left': 0.5999464392662048,
#        'Top': 1.7537433450343087e-05},
#       'Confidence': 98.66796112060547},
#      {'BoundingBox': {'Width': 0.14416393637657166,
#        'Height': 0.25744739174842834,
#        'Left': 0.7046864032745361,
#        'Top': 0.0006816304521635175},
#       'Confidence': 96.095947265625}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Animal',
#     'Confidence': 92.91004180908203,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Bag',
#     'Confidence': 55.491600036621094,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Bazaar',
#     'Confidence': 53.27967834472656,
#     'Instances': [],
#     'Parents': [{'Name': 'Market'}, {'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Bbq',
#     'Confidence': 52.27727127075195,
#     'Instances': [],
#     'Parents': [{'Name': 'Cooking'}, {'Name': 'Food'}, {'Name': 'Grilling'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Box',
#     'Confidence': 68.86441040039062,
#     'Instances': [{'BoundingBox': {'Width': 0.0809013843536377,
#        'Height': 0.058197833597660065,
#        'Left': 0.4840738773345947,
#        'Top': 0.052779585123062134},
#       'Confidence': 75.17404174804688}],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Boy',
#     'Confidence': 78.74103546142578,
#     'Instances': [{'BoundingBox': {'Width': 0.21534943580627441,
#        'Height': 0.35202786326408386,
#        'Left': 0.12162409722805023,
#        'Top': 0.0007635904476046562},
#       'Confidence': 91.3494873046875}],
#     'Parents': [{'Name': 'Male'}, {'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Butcher Shop',
#     'Confidence': 55.690826416015625,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Cafeteria',
#     'Confidence': 50.63998031616211,
#     'Instances': [],
#     'Parents': [{'Name': 'Indoors'}, {'Name': 'Restaurant'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Child',
#     'Confidence': 78.74103546142578,
#     'Instances': [{'BoundingBox': {'Width': 0.21534943580627441,
#        'Height': 0.35202786326408386,
#        'Left': 0.12162409722805023,
#        'Top': 0.0007635904476046562},
#       'Confidence': 91.3494873046875}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [{'Name': 'Kid'}],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Clam',
#     'Confidence': 92.91004180908203,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'},
#      {'Name': 'Food'},
#      {'Name': 'Invertebrate'},
#      {'Name': 'Sea Life'},
#      {'Name': 'Seafood'},
#      {'Name': 'Seashell'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Cooking',
#     'Confidence': 52.27727127075195,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Female',
#     'Confidence': 72.53848266601562,
#     'Instances': [{'BoundingBox': {'Width': 0.14416393637657166,
#        'Height': 0.25744739174842834,
#        'Left': 0.7046864032745361,
#        'Top': 0.0006816304521635175},
#       'Confidence': 96.095947265625}],
#     'Parents': [{'Name': 'Person'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Person Description'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Fish',
#     'Confidence': 52.05356216430664,
#     'Instances': [],
#     'Parents': [{'Name': 'Animal'}, {'Name': 'Sea Life'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Animals and Pets'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Food',
#     'Confidence': 92.91004180908203,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Food and Beverage'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Grilling',
#     'Confidence': 52.27727127075195,
#     'Instances': [],
#     'Parents': [{'Name': 'Cooking'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Kitchen and Dining'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Grocery Store',
#     'Confidence': 51.93684005737305,
#     'Instances': [],
#     'Parents': [{'Name': 'Shop'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Buildings and Architecture'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Handbag',
#     'Confidence': 55.491600036621094,
#     'Instances': [{'BoundingBox': {'Width': 0.037293244153261185,
#        'Height': 0.12566645443439484,
#        'Left': 0.7144228219985962,
#        'Top': 0.08572971820831299},
#       'Confidence': 55.34183883666992}],
#     'Parents': [{'Name': 'Accessories'}, {'Name': 'Bag'}],
#     'Aliases': [],
#     'Categories': [{'Name': 'Apparel and Accessories'}]}},
#   {'Timestamp': 11544,
#    'Label': {'Name': 'Indoors',
#     'Confidence': 51.68962097167969,
#     'Instances': [],
#     'Parents': [],
#     'Aliases': [],
#     'Categories': [{'Name': 'Home and Indoors'}]}}],
#  'LabelModelVersion': '3.0',
#  'JobId': '241026c5b596b63d6baeb25a430c70aa57f65428bd5204ec163cec54982f9e8f',
#  'Video': {'S3Object': {'Bucket': 'rekognition-bucket-1000',
#    'Name': 'input-output/M3_C3_Video_Label_Detection.mp4'}},
#  'GetRequestMetadata': {'SortBy': 'TIMESTAMP', 'AggregateBy': 'TIMESTAMPS'},
#  'ResponseMetadata': {'RequestId': '1d16ef37-4866-4620-a354-290268d9230b',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '1d16ef37-4866-4620-a354-290268d9230b',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '231533',
#    'date': 'Thu, 16 Oct 2025 19:28:06 GMT'},
#   'RetryAttempts': 0}}
